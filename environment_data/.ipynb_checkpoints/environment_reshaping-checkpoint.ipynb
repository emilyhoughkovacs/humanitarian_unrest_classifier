# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('environment_data.csv')

# %%
years = []
for x in range(1990, 2016):
    years.append('yr'+str(x))
print years
# Out:
# ['yr1990', 'yr1991', 'yr1992', 'yr1993', 'yr1994', 'yr1995', 'yr1996', 'yr1997', 'yr1998', 'yr1999', 'yr2000', 'yr2001', 'yr2002', 'yr2003', 'yr2004', 'yr2005', 'yr2006', 'yr2007', 'yr2008', 'yr2009', 'yr2010', 'yr2011', 'yr2012', 'yr2013', 'yr2014', 'yr2015']

# %%
df.columns = ['name', 'iso', 'series', 'series_code', 'yr1990', 'yr1991', 
              'yr1992', 'yr1993', 'yr1994', 'yr1995', 'yr1996', 'yr1997', 
              'yr1998', 'yr1999', 'yr2000', 'yr2001', 'yr2002', 'yr2003', 
              'yr2004', 'yr2005', 'yr2006', 'yr2007', 'yr2008', 'yr2009', 
              'yr2010', 'yr2011', 'yr2012', 'yr2013', 'yr2014', 'yr2015']

# %%
df.columns
# Out:
# Index([u'name', u'iso', u'series', u'series_code', u'yr1990', u'yr1991',
#        u'yr1992', u'yr1993', u'yr1994', u'yr1995', u'yr1996', u'yr1997',
#        u'yr1998', u'yr1999', u'yr2000', u'yr2001', u'yr2002', u'yr2003',
#        u'yr2004', u'yr2005', u'yr2006', u'yr2007', u'yr2008', u'yr2009',
#        u'yr2010', u'yr2011', u'yr2012', u'yr2013', u'yr2014', u'yr2015'],
#       dtype='object')

# %%
pd.unique(df['series'])
# Out:
# array([ 'Droughts, floods, extreme temperatures (% of population, average 1990-2009)',
#        'Renewable internal freshwater resources per capita (cubic meters)',
#        'Average precipitation in depth (mm per year)',
#        'Arable land (% of land area)', nan], dtype=object)

# %%
df2 = df.replace('Droughts, floods, extreme temperatures (% of population, average 1990-2009)', 'extreme')
df2 = df2.replace('Renewable internal freshwater resources per capita (cubic meters)', 'freshwater')
df2 = df2.replace('Average precipitation in depth (mm per year)', 'precipitation')
df2 = df2.replace('Arable land (% of land area)', 'arable_land')

# %%
df2 = df2.replace('..', np.nan)

# %%
df2.head()
# Out:
#         name  iso         series     series_code            yr1990  \
# 0  Argentina  ARG        extreme  EN.CLC.MDAT.ZS               NaN
# 1  Argentina  ARG     freshwater  ER.H2O.INTR.PC               NaN
# 2  Argentina  ARG  precipitation  AG.LND.PRCP.MM               NaN
# 3  Argentina  ARG    arable_land  AG.LND.ARBL.ZS  9.71063584110732
# 4  Australia  AUS        extreme  EN.CLC.MDAT.ZS               NaN
#
#              yr1991            yr1992            yr1993            yr1994  \
# 0               NaN               NaN               NaN               NaN
# 1               NaN  8676.23554422534               NaN               NaN
# 2               NaN               591               NaN               NaN
# 3  9.74900335807125  9.78737087503517  9.82573839199909  9.86520212373342
# 4               NaN               NaN               NaN               NaN
#
#              yr1995  ...              yr2006            yr2007  \
# ...

# %%
#convert columns to string type from unicode
df2.columns.astype(str).values
# Out:
# array(['name', 'iso', 'series', 'series_code', 'yr1990', 'yr1991',
#        'yr1992', 'yr1993', 'yr1994', 'yr1995', 'yr1996', 'yr1997',
#        'yr1998', 'yr1999', 'yr2000', 'yr2001', 'yr2002', 'yr2003',
#        'yr2004', 'yr2005', 'yr2006', 'yr2007', 'yr2008', 'yr2009',
#        'yr2010', 'yr2011', 'yr2012', 'yr2013', 'yr2014', 'yr2015'], dtype=object)

# %%
del df2['yr2015']

# %%
df2['mean'] = df2.iloc[:, 4:].mean(axis=1, skipna=True)

# %%
df2.head()
# Out:
#         name  iso                         series     series_code  \
# 0  Argentina  ARG  droughts_floods_extreme_temps  EN.CLC.MDAT.ZS
# 1  Argentina  ARG          freshwater_per_capita  ER.H2O.INTR.PC
# 2  Argentina  ARG            precipitation_in_mm  AG.LND.PRCP.MM
# 3  Argentina  ARG                    arable_land  AG.LND.ARBL.ZS
# 4  Australia  AUS  droughts_floods_extreme_temps  EN.CLC.MDAT.ZS
#
#              yr1990            yr1991            yr1992            yr1993  \
# 0               NaN               NaN               NaN               NaN
# 1               NaN               NaN  8676.23554422534               NaN
# 2               NaN               NaN               591               NaN
# 3  9.71063584110732  9.74900335807125  9.78737087503517  9.82573839199909
# 4               NaN               NaN               NaN               NaN
#
#              yr1994            yr1995 ...             yr2006  \
# 0               NaN               NaN ...                NaN
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 997 entries, 0 to 996
# Data columns (total 29 columns):
# name           994 non-null object
# iso            992 non-null object
# series         992 non-null object
# series_code    992 non-null object
# yr1990         205 non-null object
# yr1991         209 non-null object
# yr1992         620 non-null object
# yr1993         235 non-null object
# yr1994         235 non-null object
# yr1995         235 non-null object
# yr1996         235 non-null object
# yr1997         631 non-null object
# yr1998         235 non-null object
# yr1999         235 non-null object
# yr2000         237 non-null object
# yr2001         237 non-null object
# yr2002         635 non-null object
# yr2003         237 non-null object
# yr2004         237 non-null object
# yr2005         237 non-null object
# yr2006         239 non-null object
# yr2007         639 non-null object
# yr2008         239 non-null object
# yr2009         407 non-null object
# ...

# %%
df2.iloc[:, 4:] = df2.iloc[:, 4:].astype(float)

# %%
df2['mean'] = df2.iloc[:, 4:].mean(axis=1)

# %%
df2 = df2.fillna(df2['mean'])

# %%
df2.iloc[:, 4:-1] = df2.iloc[:, 4:-1].fillna(df2['mean'])

# %%
df2.fillna('NULL', inplace=True)

# %%
df2 = df2.iloc[:992]

# %%
df2
# Out:
#                       name  iso         series     series_code   yr1990  \
# 0                Argentina  ARG        extreme  EN.CLC.MDAT.ZS     NULL
# 1                Argentina  ARG     freshwater  ER.H2O.INTR.PC     NULL
# 2                Argentina  ARG  precipitation  AG.LND.PRCP.MM     NULL
# 3                Argentina  ARG    arable_land  AG.LND.ARBL.ZS  9.71064
# 4                Australia  AUS        extreme  EN.CLC.MDAT.ZS     NULL
# 5                Australia  AUS     freshwater  ER.H2O.INTR.PC     NULL
# 6                Australia  AUS  precipitation  AG.LND.PRCP.MM     NULL
# 7                Australia  AUS    arable_land  AG.LND.ARBL.ZS  6.23511
# 8                   Brazil  BRA        extreme  EN.CLC.MDAT.ZS     NULL
# 9                   Brazil  BRA     freshwater  ER.H2O.INTR.PC     NULL
# 10                  Brazil  BRA  precipitation  AG.LND.PRCP.MM     NULL
# 11                  Brazil  BRA    arable_land  AG.LND.ARBL.ZS  6.06367
# ...

# %%
df = df2

# %%
df.to_csv('environment_data_reshape.csv', index=False)
